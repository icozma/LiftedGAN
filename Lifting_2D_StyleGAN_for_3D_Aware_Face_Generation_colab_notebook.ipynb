# %% [markdown]
# <a href="https://colab.research.google.com/github/icozma/LiftedGAN/blob/main/Lifting_2D_StyleGAN_for_3D_Aware_Face_Generation_colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GDrive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/StyleGAN202112
# %pwd
# %ls
# Out:
# /content/drive/MyDrive/StyleGAN202112

# %% [markdown]
# # Conda

# %% [markdown]
# ## Preliminaries

# %%
# !which python # should return /usr/local/bin/python
# !python --version
# !echo $PYTHONPATH
# %env PYTHONPATH=
# Out:
# /usr/local/bin/python
# Python 3.7.12
# /env/python
# env: PYTHONPATH=

# %% [markdown]
# ## Install Conda

# %%
# %cd /content/
# Out:
# /content

# %%
# %%bash
# chmod a+rwx Miniconda3-4.5.4-Linux-x86_64.sh

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# # MINICONDA_PREFIX=/content/drive/MyDrive/StyleGAN202112/venv
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# !conda --version # should return 4.5.4
# !which python # still returns /usr/local/bin/python
# !python --version # now returns Python 3.6.5 :: Anaconda, Inc.
# Out:
# /usr/local/bin/conda
# conda 4.5.4
# /usr/local/bin/python
# Python 3.6.5 :: Anaconda, Inc.

# %% [markdown]
# ## Update Conda

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          33 KB
#     cffi-1.14.6                |   py36h400218f_0         224 KB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     ruamel_yaml-0.15.100       |   py36h27cfd23_0         268 KB
#     ld_impl_linux-64-2.35.1    |       h7274673_9         637 KB
#     openssl-1.1.1l             |       h7f8727e_0         3.8 MB
#     python-3.6.13              |       h12debd9_1        32.5 MB
#     requests-2.26.0            |     pyhd3eb1b0_0          59 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# !conda --version # should return 4.5.4
# !which python # still returns /usr/local/bin/python
# !python --version # now returns Python 3.6.5 :: Anaconda, Inc.
# Out:
# /usr/local/bin/conda
# conda 4.10.3
# /usr/local/bin/python
# Python 3.6.13 :: Anaconda, Inc.

# %% [markdown]
# ## Appending to the sys.path

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %% [markdown]
# # Clone the repository

# %%
# !git clone https://github.com/seasonSH/LiftedGAN.git
# Out:
# Cloning into 'LiftedGAN'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 112 (delta 38), reused 76 (delta 13), pack-reused 0
# Receiving objects: 100% (112/112), 70.53 KiB | 2.82 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %%bash 
# cd /content/LiftedGAN
# pwd
# ls
# Out:
# /content/LiftedGAN

# %% [markdown]
# # Create environment

# %%
# %cd /content/LiftedGAN
# !ls
# Out:
# /content/LiftedGAN
# config		    licences  README.md		 tools
# environment.yml     LICENSE   requirements.txt	 utils
# generate_images.py  models    stylegan2-pytorch

# %%
# !conda env create -f environment.yml
# Out:
# done
# done
#
# ...
# olefile-0.46         | 31 KB     | : 100% 1.0/1 [00:00<00:00,  9.27it/s]
# numpy-1.18.5         | 5 KB      | : 100% 1.0/1 [00:00<00:00,  5.70it/s]
# sip-4.19.8           | 290 KB    | : 100% 1.0/1 [00:00<00:00,  9.22it/s]
# nbconvert-5.3.1      | 406 KB    | : 100% 1.0/1 [00:00<00:00,  3.31it/s]
# webencodings-0.5.1   | 12 KB     | : 100% 1.0/1 [00:00<00:00, 19.62it/s]
# libvpx-1.7.0         | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
# sqlite-3.23.1        | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# pexpect-4.2.1        | 70 KB     | : 100% 1.0/1 [00:00<00:00, 12.55it/s]
# pywavelets-1.1.1     | 4.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
# freetype-2.10.2      | 915 KB    | : 100% 1.0/1 [00:00<00:00,  4.56it/s]
# setuptools-58.0.4    | 966 KB    | : 100% 1.0/1 [00:00<00:00,  3.81it/s]
# pandoc-2.11          | 12.5 MB   | : 100% 1.0/1 [00:03<00:00,  3.29s/it]
# pyqt-5.9.2           | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
# ...

# %%
# !conda env list
# !conda remove --name lifted_gan --all
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# lifted_gan               /usr/local/envs/lifted_gan

# %%
# %cd LiftedGAN
# %mv tools/generate_images.py .

# %% [markdown]
# # Get pretrained model 1

# %%
# !gdown https://drive.google.com/u/0/uc?id=1-44Eivt7GHINkX6zox89HHttujYWThz2&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1-44Eivt7GHINkX6zox89HHttujYWThz2
# To: /content/LiftedGAN/pretrained_liftedgan.zip
# 100% 411M/411M [00:04<00:00, 91.4MB/s]

# %%
# !unzip pretrained_liftedgan.zip
# Out:
# Archive:  pretrained_liftedgan.zip
#    creating: cats_256/
#   inflating: cats_256/config.py
#    creating: cats_256/samples/
#   inflating: cats_256/samples/20000.jpg
#   inflating: cats_256/samples/15000.jpg
#   inflating: cats_256/samples/5000.jpg
#   inflating: cats_256/samples/45000.jpg
#   inflating: cats_256/samples/30000.jpg
#   inflating: cats_256/samples/25000.jpg
#   inflating: cats_256/samples/10000.jpg
#   inflating: cats_256/samples/50000.jpg
#   inflating: cats_256/samples/40000.jpg
#   inflating: cats_256/samples/35000.jpg
#   inflating: cats_256/checkpoint_010.pth
#    creating: ffhq_256/
#    creating: ffhq_256/samples/
#   inflating: ffhq_256/samples/40000.jpg
#   inflating: ffhq_256/samples/35000.jpg
#   inflating: ffhq_256/samples/25000.jpg
#   inflating: ffhq_256/samples/50000.jpg
#   inflating: ffhq_256/samples/10000.jpg
#   inflating: ffhq_256/samples/45000.jpg
#   inflating: ffhq_256/samples/5000.jpg
#   inflating: ffhq_256/samples/30000.jpg
# ...

# %% [markdown]
# # Get pretrained model 2

# %%
# !gdown https://drive.google.com/u/0/uc?id=1qVoWu_fps17iTzYptwuN3ptgYeCpIl2e&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1qVoWu_fps17iTzYptwuN3ptgYeCpIl2e
# To: /content/LiftedGAN/pretrained.zip
# 100% 1.04G/1.04G [00:08<00:00, 130MB/s]

# %%
# !unzip pretrained.zip -d pretrained
# Out:
# Archive:  pretrained.zip
#   inflating: pretrained/inception_ffhq_cropped_256.pkl
#   inflating: pretrained/lresnet_casia.pth.tar
#   inflating: pretrained/stylegan2-cats-cropped-300000.pt
#   inflating: pretrained/stylegan2-ffhq-cropped-300000.pt

# %% [markdown]
# # Run it like there is no tomorrow

# %%
# %%bash
# source activate lifted_gan
# python generate_images.py /content/LiftedGAN/ffhq_256/checkpoint_010.pth --output_dir /content/drive/MyDrive/StyleGAN202112/results/
# Out:
# Loading generator from: ./pretrained/stylegan2-ffhq-cropped-300000.pt
# w_sigma_inv: 1.7246911525726318
# => loading checkpoint '/content/LiftedGAN/ffhq_256/checkpoint_010.pth'
# Forwarding the network...
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:04<00:00, 129MB/s]
# 100%|██████████| 3125/3125 [5:37:22<00:00,  6.28s/it]

# %%
# %%bash
# source activate lifted_gan
# python generate_poses.py /content/LiftedGAN/ffhq_256/checkpoint_010.pth --output_dir /content/drive/MyDrive/StyleGAN202112/results_poses/
# Out:
# Loading generator from: ./pretrained/stylegan2-ffhq-cropped-300000.pt
# w_sigma_inv: 1.732285976409912
# => loading checkpoint '/content/LiftedGAN/ffhq_256/checkpoint_010.pth'
# Forwarding the network...
# 100%|██████████| 7/7 [10:35<00:00, 78.45s/it]
